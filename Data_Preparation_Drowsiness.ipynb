# %%
import os
import shutil # for copy paste images
import glob
from tqdm import tqdm # it creates progress bar

# %%
Raw_DIR= r'D:\python\projects\internship\CV_Driver_Drowsiness_Detection\MRL Eye Data\mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i,dst=r'D:\python\projects\internship\CV_Driver_Drowsiness_Detection\MRL Eye Data\Prepeared Data\Close Eyes')
            
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i,dst=r'D:\python\projects\internship\CV_Driver_Drowsiness_Detection\MRL Eye Data\Prepeared Data\Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10257/10257 [01:36<00:00, 106.25it/s]
